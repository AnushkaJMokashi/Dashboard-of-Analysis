# %% [markdown]
# #Dataset Analysis dashboard part 2

# %%
## Import Relevant Packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")


pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 1000)

# %%
# Calling the dataset

df = pd.read_csv("dataset.csv")
df.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel          JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
# dim of the dataset

df.shape
# Out:
# (1470, 35)

# %%
# stats

df.describe(include = 'all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate              Department  DistanceFromHome    Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender   HourlyRate  JobInvolvement     JobLevel          JobRole  JobSatisfaction MaritalStatus  MonthlyIncome   MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
## 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
## Correlation

plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(), annot = True, linewidths=.5)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
## How many people are doing overtime

sns.countplot(df['OverTime'])
plt.xlabel("________Overtime_________")
plt.ylabel("COUNT")
plt.title("Overtime Count Plot")
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], dtype='object')

# %%
## How many people are doing Marital status

sns.countplot(df['MaritalStatus'])
plt.xlabel("__MaritalStatus__")
plt.ylabel("COUNT")
plt.title("MaritalStatus Count Plot")
plt.show()

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
## Gender

sns.countplot(df['Gender'])

# %%
## Job ROle

plt.figure(figsize = (20, 10))
sns.countplot(df['JobRole'])

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
## EducationField

plt.figure(figsize = (20, 10))
sns.countplot(df['EducationField'])

# %%
## Department

plt.figure(figsize = (20, 10))
sns.countplot(df['Department'])

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], dtype='object')

# %%
## DistanceFromHome

plt.figure(figsize = (20, 10))
sns.countplot(df['DistanceFromHome'])

# %%
## BusinessTravel

plt.figure(figsize = (20, 10))
sns.countplot(df['BusinessTravel'])

# %%
## working years

plt.figure(figsize = (20, 10))
sns.countplot(df['TotalWorkingYears'])

# %%
## NumCompaniesWorked

# Univariate Analysis => Exploring single column at a time
# cat => count

plt.figure(figsize = (20, 10))
sns.countplot(df['NumCompaniesWorked'])

# %%
df['NumCompaniesWorked'].value_counts()
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
df.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel          JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
## Age vs Overtime

# Bivariate Analysis => Analysis 2 columns at a time
# num vs cat => barplot, boxplot, swarmplot, stripplot, line chart, pie chart

# sns.stripplot(x = df['OverTime'], y = df['Age'], jitter = True)
sns.swarmplot(x = df['OverTime'], y = df['Age'])

# %%
## EDA 
# Univariate Analysis => Exploring single column at a time
# Num => hist
# cat => count

# Bivariate Analysis => Analysis 2 columns at a time
# num vs num => scatter
# num vs cat => barplot, boxplot, swarmplot, stripplot, line chart, pie chart


## Covariate Analysis => compare more than 2 columns
# heatmap, pairplot
# sns.pairplot(df)
# Bivariate Analysis VS Categorical Column

# %%
df.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel          JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
# Univariate Analysis => Exploring single column at a time
# Num => hist

plt.figure(figsize=(10, 8))
sns.distplot(df['Age'], kde = False, bins = 25, color='red')

# %%
# Bivariate Analysis => Analysis 2 columns at a time
# num vs num => scatter

plt.figure(figsize=(20, 15))
# sns.jointplot(x = df['Age'], y = df['MonthlyIncome'], color='black')

sns.jointplot(x = df['YearsAtCompany'], y = df['YearsInCurrentRole'], color='orange')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], dtype='object')

# %%
# Bivariate Analysis => Analysis 2 columns at a time
# num vs cat => barplot

plt.figure(figsize=(20, 15))
sns.barplot(x = df['PerformanceRating'], y = df['Age'])

# %%
# Bivariate Analysis VS Categorical Column

plt.figure(figsize=(20, 15))
# sns.swarmplot(x = df['OverTime'], y = df['Age'], hue = df['Gender'])
sns.boxplot(x = df['OverTime'], y = df['Age'], hue = df['Gender'])

# %%
df[  (df['OverTime'] == 'Yes') &  (df['Gender'] == 'Male') ]['Department'].value_counts()
# Out:
# Research & Development    159
# Sales                      66
# Human Resources            11
# Name: Department, dtype: int64

# %% [markdown]
# ### Analysis Groups

# %%
age = pd.DataFrame(df.groupby("Age")[['Age']]  )

age['Count'] = df['Age'].value_counts(dropna = False)

age
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-c024019de6dd> in <module>
#       6
#       7 plt.figure(figsize = (20, 10))
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], dtype='object')

# %%
age = pd.DataFrame(df.groupby("Age")[["MonthlyIncome", 'JobLevel', 'Education', 'PerformanceRating',  "JobSatisfaction", "WorkLifeBalance", 'DailyRate', 'MonthlyRate']].mean()  )
age.head()
# Out:
#      MonthlyIncome  JobLevel  Education  PerformanceRating  JobSatisfaction  WorkLifeBalance   DailyRate   MonthlyRate
# Age
# 18     1518.375000     1.000   2.500000           3.000000         3.250000         3.000000  747.625000  14476.000000
# 19     2075.000000     1.000   2.111111           3.444444         2.555556         3.222222  548.444444  15119.666667
# 20     2539.363636     1.000   2.636364           3.000000         2.636364         2.909091  819.454545  16480.909091
# 21     2491.461538     1.000   1.615385           3.153846         2.692308         2.769231  762.846154  17268.923077
# 22     2950.000000     1.125   1.812500           3.250000         2.937500         2.750000  806.937500  14424.125000

# %%
age['Count'] = df['Age'].value_counts(dropna = False)

age.reset_index(inplace = True)
age.head()
# Out:
#    Age  MonthlyIncome  JobLevel  Education  PerformanceRating  JobSatisfaction  WorkLifeBalance   DailyRate   MonthlyRate  Count
# 0   18    1518.375000     1.000   2.500000           3.000000         3.250000         3.000000  747.625000  14476.000000      8
# 1   19    2075.000000     1.000   2.111111           3.444444         2.555556         3.222222  548.444444  15119.666667      9
# 2   20    2539.363636     1.000   2.636364           3.000000         2.636364         2.909091  819.454545  16480.909091     11
# 3   21    2491.461538     1.000   1.615385           3.153846         2.692308         2.769231  762.846154  17268.923077     13
# 4   22    2950.000000     1.125   1.812500           3.250000         2.937500         2.750000  806.937500  14424.125000     16

# %%
plt.figure(figsize = (20, 10))
sns.barplot(x = age['Age'], y = age['Count'])

# %%
plt.figure(figsize = (20, 10))
sns.barplot(x = age['Age'], y = age['MonthlyIncome'])

# %%
income = pd.DataFrame( df.groupby("JobRole")[['MonthlyIncome']].mean().sort_values(by = "MonthlyIncome", ascending = False)  )
income
# income.reset_index()
# Out:
#                            MonthlyIncome
# JobRole
# Manager                     17181.676471
# Research Director           16033.550000
# Healthcare Representative    7528.763359
# Manufacturing Director       7295.137931
# Sales Executive              6924.279141
# Human Resources              4235.750000
# Research Scientist           3239.972603
# Laboratory Technician        3237.169884
# Sales Representative         2626.000000

# %%
plt.figure(figsize = (20, 10))
sns.barplot(x = income.index, y = income['MonthlyIncome'])

# %%
plt.figure(figsize= (10, 10))
plt.pie(x = income.MonthlyIncome, labels = income.index   , 
       autopct= "%1.1f%%")
plt.show()

# %%
lab_ = df.EducationField.value_counts().index
lab_
# Out:
# Index(['Life Sciences', 'Medical', 'Marketing', 'Technical Degree', 'Other', 'Human Resources'], dtype='object')

# %%
val_ = df.EducationField.value_counts().values
val_
# Out:
# array([606, 464, 159, 132,  82,  27], dtype=int64)

# %%
plt.figure(figsize= (10, 10))
plt.pie(x = val_, labels = lab_   , 
       autopct= "%1.1f%%")
plt.show()

# %% [markdown]
# Analysis :
# 1. the Count of people doing overtime < the count of people not doing overtime
# 2. HR persons are the least in numbers that cordinates and take care of all the departments
# 3. majority of people are from Life Sciences in their field of education
# 4. Since there are 3 departments, we can consider that its Product Based company with more people doing inventing and then Sales people engaged in selling.
# 5. Over 1000 people travels rarely
# 6. Majority of the employees are having around 10 yrs wrok ex.
# 7. There are employees who have worked in 9 companies also.
# 8. majority of the people live around the company
# 9. Highest people count belongs to the age group 30 - 40
# 10. Manager earns the highest while Sales representative earns the lowest.

# %%
df['colName'].fillna(value = df['colName'].mean())

# %%
# df.drop("ColName", axis = 1, inplace = True)

df.dropna()
