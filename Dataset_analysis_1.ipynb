# %% [markdown]
# ## Dataset Analysis Dashboard part 1

# %%
## import the Packages

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# import matplotlib.rcsetup

plt.style.use("fivethirtyeight")

# %%
# Call the Dataset
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
## looking at first few records of the dataset

# df.head()
df.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
# dim of the dataset
df.shape
# Out:
# (1470, 35)

# %%
# columns ???

df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# statistical parameter?

# df.describe()  # default only numerical cols

df.describe(include = 'all')  # default only numerical cols
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
# structure of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
## count of the NULL values

df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
## read the column
df['EducationField']
# Out:
# 0       Life Sciences
# 1       Life Sciences
# 2               Other
# 3       Life Sciences
# 4             Medical
#             ...
# 1465          Medical
# 1466          Medical
# 1467    Life Sciences
# 1468          Medical
# 1469          Medical
# Name: EducationField, Length: 1470, dtype: object

# %%
# read more than one column
# df[  ['EducationField'] ]

df[  ['EducationField', 'Gender', 'JobRole'] ]
# Out:
#      EducationField  Gender                    JobRole
# 0     Life Sciences  Female            Sales Executive
# 1     Life Sciences    Male         Research Scientist
# 2             Other    Male      Laboratory Technician
# 3     Life Sciences  Female         Research Scientist
# 4           Medical    Male      Laboratory Technician
# ...             ...     ...                        ...
# 1465        Medical    Male      Laboratory Technician
# 1466        Medical    Male  Healthcare Representative
# 1467  Life Sciences    Male     Manufacturing Director
# 1468        Medical    Male            Sales Executive
# 1469        Medical    Male      Laboratory Technician
#
# [1470 rows x 3 columns]

# %%
## df slicing

# df index slicing => wrt Position Number

# df.iloc[ rowIndex, colIndex  ]

# %%
df.iloc[0 : 18, 0 : 8]   # end is never included, start : end
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df.iloc[  7:25 , 11 : 13 ]
# Out:
#     Gender  HourlyRate
# 7     Male          67
# 8     Male          44
# 9     Male          94
# 10    Male          84
# 11  Female          49
# 12    Male          31
# 13    Male          93
# 14    Male          50
# 15  Female          51
# 16    Male          80
# 17    Male          96
# 18  Female          78
# 19    Male          45
# 20  Female          96
# 21    Male          82
# 22  Female          53
# 23    Male          96
# 24    Male          83

# %%
df.iloc [ 15: 17 , 14 : 17]
# Out:
#     JobLevel                 JobRole  JobSatisfaction
# 15         3  Manufacturing Director                1
# 16         1      Research Scientist                2

# %%
## Query

# select where departement is Human Resources
df[ df['Department'] == 'Human Resources' ]
# Out:
#       Age Attrition     BusinessTravel  DailyRate       Department  \
# 79     46        No      Travel_Rarely        945  Human Resources
# 100    37       Yes      Travel_Rarely        807  Human Resources
# 105    59        No         Non-Travel       1420  Human Resources
# 112    54        No         Non-Travel        142  Human Resources
# 134    26        No      Travel_Rarely       1355  Human Resources
# ...   ...       ...                ...        ...              ...
# 1379   27       Yes  Travel_Frequently       1337  Human Resources
# 1400   38        No  Travel_Frequently       1444  Human Resources
# 1401   55        No      Travel_Rarely        189  Human Resources
# 1411   25        No      Travel_Rarely        309  Human Resources
# 1450   35        No      Travel_Rarely       1146  Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 79                   5          2          Medical              1
# ...

# %%
# find managers that are married and live at min of 20 km

df[  (df['JobRole'] == 'Manager') & ( df['MaritalStatus'] == 'Married' ) & ( df['DistanceFromHome'] >= 20  )  ]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 119    43        No  Travel_Frequently        394                   Sales
# 271    47       Yes         Non-Travel        666  Research & Development
# 352    48        No      Travel_Rarely        530                   Sales
# 425    50        No      Travel_Rarely       1099  Research & Development
# 616    51        No      Travel_Rarely       1318                   Sales
# 1116   55        No      Travel_Rarely        685                   Sales
# 1154   47        No      Travel_Rarely       1176         Human Resources
# 1184   54        No      Travel_Rarely        584  Research & Development
# 1374   58        No      Travel_Rarely        605                   Sales
# 1401   55        No      Travel_Rarely        189         Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 119                 26          2    Life Sciences              1
# ...

# %%
df[  df['DistanceFromHome'] == df['DistanceFromHome'].max() ]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 61     38        No  Travel_Frequently        653  Research & Development
# 141    45        No      Travel_Rarely       1316  Research & Development
# 199    38        No      Travel_Rarely       1084  Research & Development
# 204    38       Yes      Travel_Rarely       1180  Research & Development
# 259    31       Yes  Travel_Frequently        307  Research & Development
# 271    47       Yes         Non-Travel        666  Research & Development
# 352    48        No      Travel_Rarely        530                   Sales
# 409    42        No  Travel_Frequently        532  Research & Development
# 424    57        No      Travel_Rarely        210                   Sales
# 425    50        No      Travel_Rarely       1099  Research & Development
# 460    26        No      Travel_Rarely        775                   Sales
# 604    42        No      Travel_Rarely        933  Research & Development
# ...
